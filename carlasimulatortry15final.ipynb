# %%
import carla
import random
import time
import numpy as np
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import math
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Sensor Configuration Parameters
CAMERA_WIDTH = 640
CAMERA_HEIGHT = 480
LIDAR_CHANNELS = 32
RADAR_RANGE = 100  # meters
YOLO_MODEL_PATH = 'yolov8n.pt'

class SensorProcessor:
    def __init__(self):
        self.yolo_model = YOLO(YOLO_MODEL_PATH)
        self.collision_detected = False
        self.lidar_data = None
        self.radar_data = None
        self.frame_number = 0
        self.simulation_running = True  # Flag to control simulation
        
        # Initialize plots for RADAR and LIDAR
        plt.ion()
        self.fig, (self.ax1, self.ax2) = plt.subplots(1, 2, figsize=(12, 5))
        self.lidar_scatter = self.ax1.scatter([], [], s=1)
        self.radar_scatter = self.ax2.scatter([], [], s=1)
        
        self.ax1.set_xlim(-50, 50)
        self.ax1.set_ylim(0, 100)
        self.ax1.set_xlabel('Azimuth (degrees)')
        self.ax1.set_ylabel('Depth (meters)')
        self.ax1.set_title('LIDAR Data Visualization')
        
        self.ax2.set_xlim(-50, 50)
        self.ax2.set_ylim(0, RADAR_RANGE)
        self.ax2.set_xlabel('Azimuth (degrees)')
        self.ax2.set_ylabel('Depth (meters)')
        self.ax2.set_title('RADAR Data Visualization')
        
    def camera_callback(self, image):
        try:
            img = np.reshape(np.frombuffer(image.raw_data, dtype=np.uint8),
                             (image.height, image.width, 4))[:, :, :3]
            results = self.yolo_model(img)
            annotated_img = results[0].plot()
            for det in results[0].boxes:
                cls = self.yolo_model.names[int(det.cls)]
                conf = float(det.conf)
                if cls == "person" and conf > 0.7:
                    self.handle_pedestrian_detection()
            cv2.imshow('Autonomous View', annotated_img)
            key = cv2.waitKey(1)
            if key == 27:  # Esc key
                self.simulation_running = False
        except Exception as e:
            print(f"Camera error: {str(e)}")

    def lidar_callback(self, point_cloud):
        try:
            points = np.frombuffer(point_cloud.raw_data, dtype=np.dtype('f4'))
            points = np.reshape(points, (-1, 4))[:, :3]
            self.lidar_data = points
            azimuth = np.degrees(np.arctan2(points[:, 1], points[:, 0]))
            depth = np.sqrt(points[:, 0]**2 + points[:, 1]**2)
            self.lidar_scatter.set_offsets(np.column_stack((azimuth, depth)))
            self.fig.canvas.flush_events()
            self.process_lidar_data()
        except Exception as e:
            print(f"LIDAR error: {str(e)}")

    def radar_callback(self, radar_data):
        try:
            points = np.frombuffer(radar_data.raw_data, dtype=np.dtype('f4'))
            points = np.reshape(points, (-1, 4))
            self.radar_data = points
            azimuth = np.degrees(points[:, 1])
            depth = points[:, 0]
            self.radar_scatter.set_offsets(np.column_stack((azimuth, depth)))
            self.fig.canvas.flush_events()
            self.process_radar_data()
        except Exception as e:
            print(f"RADAR error: {str(e)}")

    def process_lidar_data(self):
        if self.lidar_data is not None:
            points = self.lidar_data[(self.lidar_data[:, 0] > 0) & 
                                     (np.abs(self.lidar_data[:, 1]) < 5) &
                                     (self.lidar_data[:, 0] < 50)]
            if len(points) > 0:
                closest = np.min(points[:, 0])
                self.adjust_speed_based_on_distance(closest)

    def process_radar_data(self):
        if self.radar_data is not None:
            frontal_points = self.radar_data[(np.abs(np.degrees(self.radar_data[:, 1])) < 30) &
                                             (self.radar_data[:, 0] < RADAR_RANGE)]
            if len(frontal_points) > 0:
                closest = frontal_points[np.argmin(frontal_points[:, 0])]
                relative_velocity = closest[3]
                self.adjust_speed_based_on_velocity(relative_velocity)

    def handle_pedestrian_detection(self):
        print("Pedestrian detected! Emergency braking.")
        vehicle.apply_control(carla.VehicleControl(brake=1.0))

    def adjust_speed_based_on_distance(self, distance):
        if distance < 10:
            throttle = max(0.0, 1 - (1 / distance))
            brake = 0.5 if distance < 5 else 0.1
            control = carla.VehicleControl(throttle=throttle, brake=brake)
            vehicle.apply_control(control)

    def adjust_speed_based_on_velocity(self, relative_velocity):
        if relative_velocity < -3:
            vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.5))

# Initialize CARLA
client = carla.Client('localhost', 2000)
client.set_timeout(20.0)
world = client.get_world()

# Set synchronous mode
settings = world.get_settings()
settings.synchronous_mode = True
settings.fixed_delta_seconds = 0.05
world.apply_settings(settings)

# Setup Traffic Manager
traffic_manager = client.get_trafficmanager()
traffic_manager.set_synchronous_mode(True)
traffic_manager.global_percentage_speed_difference(-20)

# Spawn vehicle
blueprint_library = world.get_blueprint_library()
vehicle_bp = blueprint_library.filter('vehicle.lincoln.mkz')[0]
spawn_point = random.choice(world.get_map().get_spawn_points())
vehicle = world.spawn_actor(vehicle_bp, spawn_point)
vehicle.set_autopilot(True, traffic_manager.get_port())

# Create sensor processor
sensor_processor = SensorProcessor()

# Setup Camera
camera_bp = blueprint_library.find('sensor.camera.rgb')
camera_bp.set_attribute('image_size_x', str(CAMERA_WIDTH))
camera_bp.set_attribute('image_size_y', str(CAMERA_HEIGHT))
camera_transform = carla.Transform(carla.Location(x=1.5, z=2.4))
camera = world.spawn_actor(camera_bp, camera_transform, attach_to=vehicle)
camera.listen(sensor_processor.camera_callback)

# Setup LIDAR
lidar_bp = blueprint_library.find('sensor.lidar.ray_cast')
lidar_bp.set_attribute('channels', str(LIDAR_CHANNELS))
lidar_bp.set_attribute('range', '100')
lidar_bp.set_attribute('points_per_second', '100000')
lidar_transform = carla.Transform(carla.Location(z=2.5))
lidar = world.spawn_actor(lidar_bp, lidar_transform, attach_to=vehicle)
lidar.listen(sensor_processor.lidar_callback)

# Setup RADAR
radar_bp = blueprint_library.find('sensor.other.radar')
radar_bp.set_attribute('horizontal_fov', '30')
radar_bp.set_attribute('vertical_fov', '30')
radar_bp.set_attribute('range', str(RADAR_RANGE))
radar_transform = carla.Transform(carla.Location(x=2.5, z=1.0))
radar = world.spawn_actor(radar_bp, radar_transform, attach_to=vehicle)
radar.listen(sensor_processor.radar_callback)

# Spectator Camera Setup
spectator = world.get_spectator()

def update_spectator():
    vehicle_transform = vehicle.get_transform()
    vehicle_location = vehicle_transform.location
    local_offset = carla.Location(x=-6, y=0, z=4)
    camera_location = vehicle_transform.transform(local_offset)
    direction = vehicle_location - camera_location
    horizontal_distance = math.sqrt(direction.x**2 + direction.y**2)
    if horizontal_distance > 0:
        yaw = math.degrees(math.atan2(direction.y, direction.x))
        pitch = -math.degrees(math.atan2(-direction.z, horizontal_distance))
    else:
        yaw = vehicle_transform.rotation.yaw
        pitch = -90 if direction.z > 0 else 90
    spectator.set_transform(carla.Transform(camera_location, carla.Rotation(pitch=pitch, yaw=yaw)))

# Main loop with Esc key to stop
try:
    while sensor_processor.simulation_running:
        world.tick()
        update_spectator()  # Update spectator camera
except KeyboardInterrupt:
    print("Simulation stopped by user")

finally:
    settings.synchronous_mode = False
    world.apply_settings(settings)
    for actor in [camera, lidar, radar, vehicle]:
        if actor and actor.is_alive:
            actor.destroy()
    cv2.destroyAllWindows()
    sensor_processor.fig.canvas.flush_events()  # Ensure final plot update
    plt.ioff()
    plt.show()  # Keeps plots open until manually closed
    print("Simulation cleaned up")
# Out:
# 0: 480x640 2 persons, 1 fire hydrant, 38.0ms
# Speed: 8.5ms preprocess, 38.0ms inference, 211.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 fire hydrant, 58.1ms
# Speed: 4.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 fire hydrant, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 fire hydrant, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 fire hydrant, 40.2ms
# Speed: 3.0ms preprocess, 40.2ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 fire hydrant, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 traffic light, 1 fire hydrant, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 car, 1 traffic light, 1 fire hydrant, 18.1ms
# Speed: 3.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 1 fire hydrant, 23.8ms
# Speed: 3.5ms preprocess, 23.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 2 traffic lights, 1 fire hydrant, 16.6ms
# Speed: 4.0ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 2 fire hydrants, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 2 traffic lights, 2 fire hydrants, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cars, 2 traffic lights, 2 fire hydrants, 14.2ms
# Speed: 4.0ms preprocess, 14.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 airplane, 1 fire hydrant, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 airplane, 1 fire hydrant, 14.5ms
# Speed: 3.2ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 airplane, 1 fire hydrant, 16.5ms
# Speed: 3.1ms preprocess, 16.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 airplane, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 traffic light, 1 fire hydrant, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 traffic light, 1 fire hydrant, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 fire hydrant, 22.4ms
# Speed: 4.0ms preprocess, 22.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 1 traffic light, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.0ms
# Speed: 3.5ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 traffic lights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 traffic light, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 traffic light, 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 traffic light, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 traffic lights, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 17.0ms
# Speed: 3.1ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 23.9ms
# Speed: 2.2ms preprocess, 23.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 traffic lights, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 traffic lights, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 5 traffic lights, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 4 traffic lights, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 traffic lights, 15.5ms
# Speed: 4.2ms preprocess, 15.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 traffic lights, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 traffic lights, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 traffic lights, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 traffic lights, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 6 traffic lights, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 6 traffic lights, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 6 traffic lights, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 5 traffic lights, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 5 traffic lights, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 4 traffic lights, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 traffic lights, 20.1ms
# Speed: 3.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 3 traffic lights, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 5 traffic lights, 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 3 traffic lights, 16.0ms
# Speed: 2.5ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 3 traffic lights, 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 3 traffic lights, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 4 traffic lights, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 4 traffic lights, 19.6ms
# Speed: 2.5ms preprocess, 19.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 4 traffic lights, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 5 traffic lights, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 4 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 traffic lights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 traffic lights, 14.5ms
# Speed: 4.5ms preprocess, 14.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 2 traffic lights, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 4 traffic lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 3 traffic lights, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 18.0ms
# Speed: 4.5ms preprocess, 18.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 21.0ms
# Speed: 3.5ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 3 traffic lights, 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 traffic light, 19.7ms
# Speed: 2.6ms preprocess, 19.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 3 traffic lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 3 traffic lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 traffic light, 20.8ms
# Speed: 3.0ms preprocess, 20.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 traffic light, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 2 traffic lights, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 15.3ms
# Speed: 3.1ms preprocess, 15.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 16.7ms
# Speed: 3.2ms preprocess, 16.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 18.0ms
# Speed: 4.5ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 3.2ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.5ms
# Speed: 3.4ms preprocess, 17.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 16.8ms
# Speed: 4.0ms preprocess, 16.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 19.0ms
# Speed: 3.5ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.6ms
# Speed: 4.0ms preprocess, 16.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 18.0ms
# Speed: 3.5ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.6ms
# Speed: 4.0ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.1ms
# Speed: 3.5ms preprocess, 14.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 2 traffic lights, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 2 traffic lights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.6ms
# Speed: 4.0ms preprocess, 16.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 2 traffic lights, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 21.0ms
# Speed: 2.5ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 20.0ms
# Speed: 3.3ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 18.8ms
# Speed: 3.0ms preprocess, 18.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 3.3ms preprocess, 14.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.1ms
# Speed: 2.5ms preprocess, 16.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 1 traffic light, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cars, 1 traffic light, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 car, 1 traffic light, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 5 cars, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 cars, 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 23.2ms
# Speed: 3.0ms preprocess, 23.2ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 21.0ms
# Speed: 2.5ms preprocess, 21.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 28.5ms
# Speed: 2.0ms preprocess, 28.5ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 cars, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 27.5ms
# Speed: 1.5ms preprocess, 27.5ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cars, 30.5ms
# Speed: 3.5ms preprocess, 30.5ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 bench, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 bench, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 clock, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 1 clock, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 32.5ms
# Speed: 4.5ms preprocess, 32.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 23.2ms
# Speed: 1.5ms preprocess, 23.2ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.5ms
# Speed: 4.0ms preprocess, 22.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 28.7ms
# Speed: 2.0ms preprocess, 28.7ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 26.0ms
# Speed: 3.0ms preprocess, 26.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 25.2ms
# Speed: 2.5ms preprocess, 25.2ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 32.0ms
# Speed: 3.5ms preprocess, 32.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 29.4ms
# Speed: 3.0ms preprocess, 29.4ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 25.6ms
# Speed: 3.0ms preprocess, 25.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 3 traffic lights, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 2 traffic lights, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 27.5ms
# Speed: 2.9ms preprocess, 27.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 22.0ms
# Speed: 2.5ms preprocess, 22.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 2 traffic lights, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 3 traffic lights, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 23.0ms
# Speed: 3.5ms preprocess, 23.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 traffic light, 29.0ms
# Speed: 3.5ms preprocess, 29.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 21.0ms
# Speed: 3.1ms preprocess, 21.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 26.0ms
# Speed: 3.3ms preprocess, 26.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 28.0ms
# Speed: 2.5ms preprocess, 28.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 2 traffic lights, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 1 traffic light, 27.5ms
# Speed: 3.0ms preprocess, 27.5ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 22.5ms
# Speed: 3.0ms preprocess, 22.5ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 26.5ms
# Speed: 3.0ms preprocess, 26.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 19.0ms
# Speed: 2.2ms preprocess, 19.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 30.5ms
# Speed: 2.1ms preprocess, 30.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 traffic lights, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 traffic lights, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 trucks, 26.1ms
# Speed: 3.0ms preprocess, 26.1ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 23.6ms
# Speed: 2.5ms preprocess, 23.6ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 24.1ms
# Speed: 4.0ms preprocess, 24.1ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.3ms
# Speed: 3.0ms preprocess, 22.3ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 2 traffic lights, 23.0ms
# Speed: 2.5ms preprocess, 23.0ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 30.6ms
# Speed: 3.5ms preprocess, 30.6ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 29.5ms
# Speed: 3.5ms preprocess, 29.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 traffic light, 19.4ms
# Speed: 3.2ms preprocess, 19.4ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 19.5ms
# Speed: 2.5ms preprocess, 19.5ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 31.4ms
# Speed: 3.0ms preprocess, 31.4ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 truck, 1 traffic light, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 truck, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 traffic light, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 traffic light, 1 bird, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 24.5ms
# Speed: 3.1ms preprocess, 24.5ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
